# %%
from pathlib import Path
import json
import os
import random
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tokenizers import BertWordPieceTokenizer
from transformers import BertTokenizer, TFBertModel

# %%
def read_squad(path):
    path = Path(path)
    with open(path, 'rb') as f:
        squad = json.load(f)
        

    contexts = []
    questions = []
    answers= []
    for group in squad['data']:
        for passage in group['paragraphs']:
            context = passage['context']
            for qa in passage['qas']:
                question = qa['question']
                for answer in qa['answers']:
                    contexts.append(context)
                    questions.append(question)
                    answers.append(answer)

    return contexts, questions, answers

contexts, questions, answers = read_squad('train-v2.0.json')
data={"contexts":contexts,"ques":questions,"ans":answers}
df = pd.DataFrame.from_dict(data)
train,test= train_test_split(df, test_size=0.2)
train_contexts=train["contexts"].values.tolist()
train_questions=train["ques"].values.tolist()
train_answers=train["ans"].values.tolist()

train_df={'train_contexts':train_contexts, 'train_questions':train_questions, 'train_answers':train_answers}

test_contexts=test["contexts"].values.tolist()
test_questions=test["ques"].values.tolist()
test_answers=test["ans"].values.tolist()

test_df={'test_contexts':test_contexts ,'test_questions':test_questions, 'test_answers':test_answers}

# %%
def clean(df):
    for key in df.keys():
        df[key]=list(map(lambda x: " ".join(str(x).split()), df[key]))

# %%
train_answers
# Out:
# [{'text': 'John F. Kennedy, James Monroe, Taft, Theodore Roosevelt, Adlai Stevenson, Evander Childs, Christopher Columbus, Morris, Walton, and South Bronx High Schools',
#   'answer_start': 281},
#  {'text': 'Chinese character dictionaries', 'answer_start': 0},
#  {'text': '2007', 'answer_start': 80},
#  {'text': "People's Daily", 'answer_start': 17},
#  {'text': 'MiMo', 'answer_start': 512},
#  {'text': 'Diego Maradona', 'answer_start': 702},
#  {'text': 'both single leg and double leg work', 'answer_start': 41},
#  {'text': 'a few days', 'answer_start': 178},
#  {'text': 'administrator von Kállay', 'answer_start': 1287},
#  {'text': 'Frederick the Great,', 'answer_start': 0},
#  {'text': '"going negative" carries risks', 'answer_start': 800},
#  {'text': 'a formal clergy-laity division', 'answer_start': 695},
#  {'text': 'decisive experiments', 'answer_start': 263},
#  {'text': 'Chittenden Avenue', 'answer_start': 92},
#  {'text': 'extreme programming and the agile software development',
#   'answer_start': 56},
#  {'text': 'eight major towns', 'answer_start': 684},
#  {'text': 'two', 'answer_start': 263},
#  {'text': 'NES', 'answer_start': 225},
#  {'text': 'Afega', 'answer_start': 559},
#  {'text': 'Apollo-Soyuz', 'answer_start': 1172},
#  {'text': '120 million', 'answer_start': 104},
#  {'text': '47', 'answer_start': 484},
#  {'text': 'Beaux-Arts', 'answer_start': 274},
#  {'text': 'religion', 'answer_start': 313},
#  {'text': 'encryption hardware', 'answer_start': 35},
#  {'text': 'Northeast', 'answer_start': 173},
#  {'text': 'Shanghai', 'answer_start': 488},
#  {'text': 'Doctors, engineers, teachers, lawyers, journalists',
#   'answer_start': 725},
#  {'text': 'Auguste Franchomme', 'answer_start': 234},
#  {'text': 'Greek', 'answer_start': 648},
#  {'text': 'monarchy', 'answer_start': 242},
#  {'text': 'Prefect of Egypt', 'answer_start': 513},
#  {'text': '5000 years', 'answer_start': 53},
#  {'text': 'Tollywood', 'answer_start': 455},
#  {'text': 'Matica hrvatska and Matica srpska', 'answer_start': 635},
#  {'text': "L'Oréal", 'answer_start': 335},
#  {'text': '3rd century BCE to the 4th century CE', 'answer_start': 63},
#  {'text': 'Diwali', 'answer_start': 28},
#  {'text': 'Bud Tribble, a member of the Mac team', 'answer_start': 226},
#  {'text': 'Brazil', 'answer_start': 688},
#  {'text': 'knew Greek', 'answer_start': 11},
#  {'text': '40 minutes', 'answer_start': 1164},
#  {'text': '6.1 million', 'answer_start': 276},
#  {'text': 'Bartélemy Lebrun', 'answer_start': 236},
#  {'text': 'Liangzhu', 'answer_start': 253},
#  {'text': '1.3 million', 'answer_start': 496},
#  {'text': 'The Natufian period', 'answer_start': 294},
#  {'text': '1891', 'answer_start': 290},
#  {'text': 'until a loss or until the end of the sports season',
#   'answer_start': 506},
#  {'text': 'Duke of Clermont', 'answer_start': 370},
#  {'text': '1916', 'answer_start': 206},
#  {'text': 'New York', 'answer_start': 256},
#  {'text': '2', 'answer_start': 17},
#  {'text': '218', 'answer_start': 373},
#  {'text': '18 approvals', 'answer_start': 478},
#  {'text': 'magnetic field losses', 'answer_start': 781},
#  {'text': 'declawed and muzzled', 'answer_start': 130},
#  {'text': 'Palais du Rhin', 'answer_start': 572},
#  {'text': 'winter food supply', 'answer_start': 244},
#  {'text': '1890s', 'answer_start': 83},
#  {'text': 'early', 'answer_start': 50},
#  {'text': 'Anthony Quinn', 'answer_start': 46},
#  {'text': 'SQL', 'answer_start': 700},
#  {'text': 'the Tobolar Copra processing plant', 'answer_start': 39},
#  {'text': 'Kingston', 'answer_start': 523},
#  {'text': 'nearly 4,000 deaths', 'answer_start': 369},
#  {'text': 'nobles', 'answer_start': 245},
#  {'text': 'world events', 'answer_start': 454},
#  {'text': 'Henri Bergson', 'answer_start': 183},
#  {'text': 'the brown men', 'answer_start': 32},
#  {'text': 'actively seek to promote an inclusive workplace',
#   'answer_start': 369},
#  {'text': '272,481', 'answer_start': 118},
#  {'text': '29', 'answer_start': 120},
#  {'text': '64 per cent', 'answer_start': 398},
#  {'text': 'full union', 'answer_start': 104},
#  {'text': '1915', 'answer_start': 573},
#  {'text': '80 percent', 'answer_start': 619},
#  {'text': 'the cross', 'answer_start': 479},
#  {'text': '1831', 'answer_start': 1246},
#  {'text': 'gombeenism', 'answer_start': 78},
#  {'text': 'literal or an allegorical aspect', 'answer_start': 44},
#  {'text': "in the palace's Ballroom", 'answer_start': 111},
#  {'text': 'lush coal swamps', 'answer_start': 448},
#  {'text': 'short vertical antenna', 'answer_start': 256},
#  {'text': 'tuning forks', 'answer_start': 638},
#  {'text': 'Formerly huge gene pools of various wild and indigenous breeds have collapsed causing widespread genetic erosion',
#   'answer_start': 392},
#  {'text': 'North German coasts', 'answer_start': 68},
#  {'text': 'ale', 'answer_start': 226},
#  {'text': '1,500', 'answer_start': 940},
#  {'text': 'Avenida de los Insurgentes', 'answer_start': 588},
#  {'text': 'marrying early and being very conservative', 'answer_start': 465},
#  {'text': '1,000 mm (39.4 in', 'answer_start': 339},
#  {'text': 'It sees every object as distinct and discrete from all other objects.',
#   'answer_start': 83},
#  {'text': 'the Young Turk Revolution', 'answer_start': 149},
#  {'text': 'longer playback time', 'answer_start': 537},
#  {'text': '4.3', 'answer_start': 282},
#  {'text': 'yellow card', 'answer_start': 75},
#  {'text': '1788', 'answer_start': 43},
#  {'text': 'basement area', 'answer_start': 543},
#  {'text': 'Sisvel', 'answer_start': 163},
#  {'text': 'torrid', 'answer_start': 17},
#  {'text': 'Switzerland', 'answer_start': 559},
#  {'text': 'Frisians', 'answer_start': 207},
#  {'text': '3.5 metres', 'answer_start': 329},
#  {'text': 'how strongly the fossil record is biased by the greater availability and preservation of recent geologic sections.',
#   'answer_start': 186},
#  {'text': 'Early Islamic philosophy', 'answer_start': 157},
#  {'text': 'fear', 'answer_start': 1013},
#  {'text': '1945', 'answer_start': 118},
#  {'text': 'disc-loader', 'answer_start': 351},
#  {'text': 'A.C. Underwood and William R. Estep. Gourley', 'answer_start': 451},
#  {'text': 'eight percent', 'answer_start': 489},
#  {'text': 'the proceeds from the Berkshire Hathaway shares he still owns at death are to be used for philanthropic purposes within 10 years',
#   'answer_start': 645},
#  {'text': 'over $180 billion', 'answer_start': 466},
#  {'text': 'Richard Taunton Sixth Form College', 'answer_start': 119},
#  {'text': 'Pierre Blanchar', 'answer_start': 330},
#  {'text': 'Sikh religion', 'answer_start': 45},
#  {'text': 'individual football associations', 'answer_start': 706},
#  {'text': 'The first 45 rpm record created for sale', 'answer_start': 720},
#  {'text': '1906', 'answer_start': 3},
#  {'text': 'Bohras', 'answer_start': 229},
#  {'text': 'Països Catalans', 'answer_start': 51},
#  {'text': 'Raisina Hill', 'answer_start': 176},
#  {'text': '20,000', 'answer_start': 1163},
#  {'text': 'C++', 'answer_start': 313},
#  {'text': 'Castle Bravo', 'answer_start': 252},
#  {'text': 'four', 'answer_start': 295},
#  {'text': 'n March 2006, the foundation announced a US$5 million grant for the International Justice Mission (IJM)',
#   'answer_start': 1},
#  {'text': '$20.67', 'answer_start': 181},
#  {'text': "to dispense beer from a cask or container in a pub's basement or cellar",
#   'answer_start': 94},
#  {'text': '1854', 'answer_start': 5},
#  {'text': 'Ferrol', 'answer_start': 51},
#  {'text': 'Ethiopians', 'answer_start': 205},
#  {'text': 'Baptists', 'answer_start': 0},
#  {'text': '1850', 'answer_start': 234},
#  {'text': '325-mile', 'answer_start': 998},
#  {'text': 'The Orthodox millet', 'answer_start': 139},
#  {'text': 'Proto-Iranian', 'answer_start': 78},
#  {'text': 'migratory birds', 'answer_start': 422},
#  {'text': 'electrical pulses', 'answer_start': 303},
#  {'text': 'movements', 'answer_start': 66},
#  {'text': 'Biblical references', 'answer_start': 705},
#  {'text': 'neuter', 'answer_start': 393},
#  {'text': '14', 'answer_start': 643},
#  {'text': "promoting England's bid to win the World Cup", 'answer_start': 502},
#  {'text': '28', 'answer_start': 195},
#  {'text': '1453', 'answer_start': 124},
#  {'text': 'instrumental in transmitting the ideas of western romantic nationalism and philhellenism, which together with the conception of Hellenism,',
#   'answer_start': 473},
#  {'text': 'Saint-Domingue', 'answer_start': 83},
#  {'text': 'support', 'answer_start': 160},
#  {'text': "under that electoral system only votes for the president's position were cast, with the runner-up in the Electoral College becoming vice president",
#   'answer_start': 633},
#  {'text': 'risk inherent with financial innovation', 'answer_start': 77},
#  {'text': 'Terminator 2: Judgment Day', 'answer_start': 81},
#  {'text': 'absorb', 'answer_start': 106},
#  {'text': 'in', 'answer_start': 6},
#  {'text': '1729', 'answer_start': 756},
#  {'text': 'colonies', 'answer_start': 157},
#  {'text': 'The Age of Reason', 'answer_start': 129},
#  {'text': 'Geneva', 'answer_start': 265},
#  {'text': '12 December 1911', 'answer_start': 3},
#  {'text': 'extensions for characters outside the English alphabet and symbols used outside the United States',
#   'answer_start': 145},
#  {'text': 'Birds', 'answer_start': 0},
#  {'text': 'Western Railroad', 'answer_start': 391},
#  {'text': 'political insurrection', 'answer_start': 188},
#  {'text': 'medical schools', 'answer_start': 290},
#  {'text': 'Best Places for Business and Careers', 'answer_start': 107},
#  {'text': 'new nations', 'answer_start': 32},
#  {'text': 'pre-inaugural', 'answer_start': 344},
#  {'text': 'two', 'answer_start': 15},
#  {'text': 'Consumer Electronics Shows', 'answer_start': 28},
#  {'text': 'fine-grained polycrystalline form', 'answer_start': 838},
#  {'text': '1974', 'answer_start': 3},
#  {'text': 'Andrea Gabrieli', 'answer_start': 1147},
#  {'text': 'Detection of prey', 'answer_start': 71},
#  {'text': 'Nursing', 'answer_start': 276},
#  {'text': 'acting in character', 'answer_start': 637},
#  {'text': 'to rise', 'answer_start': 137},
#  {'text': 'Breton Island', 'answer_start': 94},
#  {'text': 'average of 2,500', 'answer_start': 71},
#  {'text': '1902', 'answer_start': 73},
#  {'text': 'political sentiments of the time', 'answer_start': 217},
#  {'text': '16.3 °C (61.3 °F)', 'answer_start': 219},
#  {'text': 'died within two weeks', 'answer_start': 155},
#  {'text': 'Austria and Prussia', 'answer_start': 110},
#  {'text': 'intellectual skeptic', 'answer_start': 449},
#  {'text': 'sense of smell', 'answer_start': 362},
#  {'text': 'Somali Telecommunication Association', 'answer_start': 4},
#  {'text': '2007', 'answer_start': 547},
#  {'text': 'All of the highways', 'answer_start': 0},
#  {'text': 'vinyl or polystyrene', 'answer_start': 669},
#  {'text': 'early 19th century', 'answer_start': 285},
#  {'text': 'Second Vatican Council', 'answer_start': 505},
#  {'text': '1938', 'answer_start': 464},
#  {'text': '820-foot-long (250 m)', 'answer_start': 116},
#  {'text': 'Plymouth City Airport', 'answer_start': 595},
#  {'text': 'William of Wrotham', 'answer_start': 359},
#  {'text': 'United States Senate', 'answer_start': 97},
#  {'text': 'they are what the thing is', 'answer_start': 507},
#  {'text': 'antimony', 'answer_start': 31},
#  {'text': '4°N and 5°S', 'answer_start': 111},
#  {'text': 'modify wood', 'answer_start': 326},
#  {'text': 'Murano', 'answer_start': 169},
#  {'text': 'drops at low temperatures', 'answer_start': 502},
#  {'text': 'Largely due to the displacement of baskets with plastic bags and cardboard boxes, the industry has severely declined since the 1950s',
#   'answer_start': 585},
#  {'text': 'National Association of Broadcasters', 'answer_start': 314},
#  {'text': 'Blundy and Lycett', 'answer_start': 486},
#  {'text': 'express or implied', 'answer_start': 58},
#  {'text': 'report tracking and multipath characteristics of the “I” signals on E2 and E5B',
#   'answer_start': 428},
#  {'text': 'state of the masses', 'answer_start': 92},
#  {'text': '1918', 'answer_start': 74},
#  {'text': 'the Somali diaspora', 'answer_start': 245},
#  {'text': 'the cross of Saint George', 'answer_start': 505},
#  {'text': 'north', 'answer_start': 7},
#  {'text': 'hundreds of years', 'answer_start': 183},
#  {'text': 'Greater Boston', 'answer_start': 29},
#  {'text': '607', 'answer_start': 702},
#  {'text': 'October 16, 2015', 'answer_start': 548},
#  {'text': 'romantic sentimental ballads', 'answer_start': 31},
#  {'text': 'natural', 'answer_start': 104},
#  {'text': 'two', 'answer_start': 1603},
#  {'text': 'land-owners', 'answer_start': 116},
#  {'text': 'president', 'answer_start': 149},
#  {'text': 'National Bank of Tuvalu', 'answer_start': 37},
#  {'text': 'from conception to death.', 'answer_start': 141},
#  {'text': 'the sovereign or by Lords Commissioners', 'answer_start': 376},
#  {'text': 'Danny Cohen', 'answer_start': 311},
#  {'text': 'full autonomy', 'answer_start': 404},
#  {'text': 'Sorry', 'answer_start': 776},
#  {'text': 'Chicago', 'answer_start': 620},
#  {'text': '16th-century Protestants', 'answer_start': 428},
#  {'text': 'realism and naturalism', 'answer_start': 450},
#  {'text': 'dried coconut fibre', 'answer_start': 520},
#  {'text': 'copper', 'answer_start': 65},
#  {'text': 'children from parents', 'answer_start': 1050},
#  {'text': 'January 21, 1985', 'answer_start': 303},
#  {'text': '10 billion', 'answer_start': 308},
#  {'text': 'Easter Sunday', 'answer_start': 495},
#  {'text': 'Athanasius Against the World', 'answer_start': 801},
#  {'text': '2017', 'answer_start': 328},
#  {'text': 'philosopher Gemistus Pletho, who abandoned Christianity.',
#   'answer_start': 409},
#  {'text': 'music', 'answer_start': 98},
#  {'text': '1479–1480', 'answer_start': 115},
#  {'text': 'Until 2004', 'answer_start': 101},
#  {'text': 'Continental Scandinavian languages', 'answer_start': 332},
#  {'text': 'John DeStefano, Jr.', 'answer_start': 5},
#  {'text': 'Charles I', 'answer_start': 70},
#  {'text': 'climatic change', 'answer_start': 91},
#  {'text': 'Evanston', 'answer_start': 15},
#  {'text': 'construction', 'answer_start': 297},
#  {'text': "Tito's", 'answer_start': 110},
#  {'text': 'more power than is permitted by the specifications for a single port.',
#   'answer_start': 25},
#  {'text': 'Indira Gandhi Indoor Stadium', 'answer_start': 91},
#  {'text': 'Boy George', 'answer_start': 369},
#  {'text': 'atheistic', 'answer_start': 276},
#  {'text': 'whether Dean was the victim of media bias', 'answer_start': 617},
#  {'text': 'The Arians no longer presented an unbroken front',
#   'answer_start': 0},
#  {'text': 'Sacred Edict of 1670', 'answer_start': 506},
#  {'text': 'Cambridge', 'answer_start': 787},
#  {'text': 'that the sun will continue to rise in the East',
#   'answer_start': 828},
#  {'text': 'from 5:00 p.m. to 6:30 p.m.', 'answer_start': 136},
#  {'text': 'Tony Curtis', 'answer_start': 98},
#  {'text': 'Somali Studies', 'answer_start': 83},
#  {'text': 'mid-1990s', 'answer_start': 553},
#  {'text': '24', 'answer_start': 637},
#  {'text': 'second', 'answer_start': 486},
#  {'text': 'genetic framework for migratory behavior', 'answer_start': 358},
#  {'text': 'centuries', 'answer_start': 184},
#  {'text': 'indigenous, Mediterranean, African and Western',
#   'answer_start': 36},
#  {'text': 'The United States Code', 'answer_start': 161},
#  {'text': 'Chengdu', 'answer_start': 104},
#  {'text': 'invalidate that consent', 'answer_start': 346},
#  {'text': '2013', 'answer_start': 35},
#  {'text': "Queen's Tower", 'answer_start': 759},
#  {'text': 'four', 'answer_start': 24},
#  {'text': '60,000 troops', 'answer_start': 313},
#  {'text': "Establishing the President's Committee on Equality of Treatment and Opportunity in the Armed Services",
#   'answer_start': 632},
#  {'text': '1991', 'answer_start': 95},
#  {'text': 'sexual orientation', 'answer_start': 71},
#  {'text': 'disclosure/labeling requirements', 'answer_start': 834},
#  {'text': 'causal efficacy', 'answer_start': 20},
#  {'text': 'Northcliffe estate', 'answer_start': 84},
#  {'text': '38', 'answer_start': 236},
#  {'text': '15 million', 'answer_start': 73},
#  {'text': 'low radiation resistance', 'answer_start': 389},
#  {'text': 'Fritz Klein', 'answer_start': 102},
#  {'text': 'free-to-air', 'answer_start': 290},
#  {'text': 'young men', 'answer_start': 32},
#  {'text': '1995', 'answer_start': 3},
#  {'text': 'Glory', 'answer_start': 160},
#  {'text': 'raising taxes', 'answer_start': 316},
#  {'text': 'Jack Kirby', 'answer_start': 602},
#  {'text': 'batteries', 'answer_start': 580},
#  {'text': 'heritage regulations', 'answer_start': 115},
#  {'text': 'Abdullah Senussi', 'answer_start': 102},
#  {'text': 'Fontainebleau', 'answer_start': 470},
#  {'text': 'Plutarco Elias Calles', 'answer_start': 506},
#  {'text': 'French reinforcements were blocked by British naval victory in the Battle of Cartagena',
#   'answer_start': 127},
#  {'text': 'over 3,000', 'answer_start': 544},
#  {'text': 'English and a creole language known as Norfuk', 'answer_start': 21},
#  {'text': 'speech', 'answer_start': 408},
#  {'text': 'Rostov on Don', 'answer_start': 422},
#  {'text': 'ritual crew of devils', 'answer_start': 431},
#  {'text': 'General Goddard', 'answer_start': 711},
#  {'text': 'the United States Marine Corps', 'answer_start': 1307},
#  {'text': 'June 16, 1911', 'answer_start': 3},
#  {'text': 'The Daily Universal Register', 'answer_start': 68},
#  {'text': 'second half of the 20th century', 'answer_start': 9},
#  {'text': 'three-step', 'answer_start': 3126},
#  {'text': 'adultery', 'answer_start': 664},
#  {'text': 'media', 'answer_start': 66},
#  {'text': 'different theological views', 'answer_start': 83},
#  {'text': 'Itō Hirobumi and Li Hongzhang', 'answer_start': 171},
#  {'text': 'agriculture', 'answer_start': 437},
#  {'text': 'more than 7,000 pages', 'answer_start': 172},
#  {'text': 'Western thought', 'answer_start': 437},
#  {'text': 'communication skills and personality', 'answer_start': 1032},
#  {'text': 'Downtown', 'answer_start': 520},
#  {'text': "The company's mainstay business", 'answer_start': 161},
#  {'text': '2007', 'answer_start': 504},
#  {'text': 'Nelson Mandela', 'answer_start': 563},
#  {'text': '1978', 'answer_start': 12},
#  {'text': '1999', 'answer_start': 295},
#  {'text': 'allow Japan free rein in Asia', 'answer_start': 661},
#  {'text': '1853', 'answer_start': 88},
#  {'text': 'Tom Buchanan', 'answer_start': 697},
#  {'text': 'Lower recorded volume', 'answer_start': 966},
#  {'text': 'tenth', 'answer_start': 318},
#  {'text': '2013', 'answer_start': 965},
#  {'text': 'diagnostic keys', 'answer_start': 359},
#  {'text': '4.5 million', 'answer_start': 80},
#  {'text': 'scavengers', 'answer_start': 420},
#  {'text': '1902', 'answer_start': 3},
#  {'text': 'Seattle Sounders FC', 'answer_start': 347},
#  {'text': 'Two schoolboys from Eton College', 'answer_start': 188},
#  {'text': '10,000', 'answer_start': 1304},
#  {'text': 'Spain', 'answer_start': 332},
#  {'text': '290 kilometers', 'answer_start': 79},
#  {'text': 'private investment in the public markets', 'answer_start': 30},
#  {'text': 'Calendar (New Style) Act 1750', 'answer_start': 689},
#  {'text': 'John F. Kennedy', 'answer_start': 420},
#  {'text': '29 April 1979', 'answer_start': 80},
#  {'text': 'saw purpose in this type of asymmetric enterprise',
#   'answer_start': 114},
#  {'text': 'using a single-lens microscope of his own design',
#   'answer_start': 88},
#  {'text': '150', 'answer_start': 760},
#  {'text': '1836', 'answer_start': 230},
#  {'text': 'Denial of service attacks', 'answer_start': 0},
#  {'text': 'the hypothalamus,', 'answer_start': 70},
#  {'text': 'Municipal Corporation of Delhi (MCD)', 'answer_start': 172},
#  {'text': 'ten minutes playing time per side', 'answer_start': 277},
#  {'text': 'May to September', 'answer_start': 168},
#  {'text': '1228–1826', 'answer_start': 14},
#  {'text': 'Amistad', 'answer_start': 362},
#  {'text': '25,000-30,', 'answer_start': 289},
#  {'text': '2.79', 'answer_start': 661},
#  {'text': 'Turkish', 'answer_start': 659},
#  {'text': 'CAN/CSA B44 Safety Standard', 'answer_start': 383},
#  {'text': '943 mb', 'answer_start': 548},
#  {'text': 'past human groups', 'answer_start': 501},
#  {'text': '1798', 'answer_start': 1202},
#  {'text': 'largest', 'answer_start': 185},
#  {'text': 'Universal Studios', 'answer_start': 67},
#  {'text': 'this would maximize the opportunities for editorial judgment',
#   'answer_start': 560},
#  {'text': 'U.K.', 'answer_start': 172},
#  {'text': '1949', 'answer_start': 308},
#  {'text': 'Brian Dunkleman', 'answer_start': 142},
#  {'text': 'the body systems, pathogens, and immunity', 'answer_start': 111},
#  {'text': 'Charophycean green algae', 'answer_start': 432},
#  {'text': 'United States Department of Education', 'answer_start': 730},
#  {'text': 'pasta', 'answer_start': 379},
#  {'text': 'May 21, 2008', 'answer_start': 78},
#  {'text': 'the Temple in Jerusalem', 'answer_start': 144},
#  {'text': 'biomass and waste recycling', 'answer_start': 263},
#  {'text': 'John A. Quitman', 'answer_start': 61},
#  {'text': 'kebun binatang', 'answer_start': 635},
#  {'text': "art for art's sake", 'answer_start': 56},
#  {'text': 'to see', 'answer_start': 107},
#  {'text': 'Windsor–Detroit International Freedom Festival',
#   'answer_start': 576},
#  {'text': '19th century', 'answer_start': 148},
#  {'text': 'Commodore Robert F. Stockton', 'answer_start': 895},
#  {'text': 'Triacastela', 'answer_start': 109},
#  {'text': 'American Revolution', 'answer_start': 179},
#  {'text': 'to deride Canada as an unimportant neighbor', 'answer_start': 223},
#  {'text': 'Wiz Khalifa', 'answer_start': 658},
#  {'text': 'indifferent', 'answer_start': 500},
#  {'text': 'his work on the photo-electric effect', 'answer_start': 624},
#  {'text': 'Seafood is a common ingredient in coastal cities',
#   'answer_start': 74},
#  {'text': '46 BC', 'answer_start': 296},
#  {'text': 'western New Haven', 'answer_start': 176},
#  {'text': '1953', 'answer_start': 144},
#  {'text': 'the vinaya', 'answer_start': 530},
#  {'text': 'for decorative effect', 'answer_start': 459},
#  {'text': 'many lines', 'answer_start': 621},
#  {'text': 'a theatrical spectacle', 'answer_start': 1012},
#  {'text': 'the same underlying cause as sexual orientation itself',
#   'answer_start': 927},
#  {'text': '10 percent', 'answer_start': 404},
#  {'text': 'Kaysanites Shia', 'answer_start': 43},
#  {'text': 'Walter Sabo', 'answer_start': 480},
#  {'text': 'Windsor Castle', 'answer_start': 565},
#  {'text': 'The Brethren', 'answer_start': 528},
#  {'text': 'Oman', 'answer_start': 462},
#  {'text': 'indigenous Americans', 'answer_start': 33},
#  {'text': 'Robert "Evel" Knievel', 'answer_start': 18},
#  {'text': 'higher', 'answer_start': 173},
#  {'text': 'crusade', 'answer_start': 158},
#  {'text': '2020', 'answer_start': 464},
#  {'text': 'mistakes the nature of the conservative outlook',
#   'answer_start': 85},
#  {'text': 'Margaret Thatcher', 'answer_start': 441},
#  {'text': 'more than a week', 'answer_start': 135},
#  {'text': 'the cathedral church', 'answer_start': 328},
#  {'text': 'murder by government', 'answer_start': 86},
#  {'text': 'Southampton Solent University', 'answer_start': 81},
#  {'text': '3,400', 'answer_start': 231},
#  {'text': 'drum loops and short samples', 'answer_start': 117},
#  {'text': 'Wii Remote', 'answer_start': 171},
#  {'text': 'eleven', 'answer_start': 354},
#  {'text': 'Colonel Rose', 'answer_start': 230},
#  {'text': 'Kanaleneiland, Overvecht and Hoograven consist primarily of high-rise housing developments, and are known for relatively high poverty and crime rate',
#   'answer_start': 669},
#  {'text': 'Kiran Bedi', 'answer_start': 83},
#  {'text': 'James Anderson', 'answer_start': 54},
#  {'text': 'Main Street Station', 'answer_start': 479},
#  {'text': 'Deputy Chairman of the Executive Council of Myanmar',
#   'answer_start': 410},
#  {'text': 'wrote separate letters to the President of the United States Barack Obama',
#   'answer_start': 145},
#  {'text': 'Nintendo Advanced Video Gaming System', 'answer_start': 196},
#  {'text': 'Bedouin', 'answer_start': 811},
#  {'text': 'premium', 'answer_start': 258},
#  {'text': 'non-Commonwealth countries', 'answer_start': 3},
#  {'text': 'plant pathogens, weeds, mollusks', 'answer_start': 220},
#  {'text': 'James VI, King of Scots', 'answer_start': 9},
#  {'text': 'John Goldsmith', 'answer_start': 8},
#  {'text': 'Clerk of the Parliaments', 'answer_start': 90},
#  {'text': 'the need for making compensation based on the time',
#   'answer_start': 130},
#  {'text': 'The Salon Cubists', 'answer_start': 345},
#  {'text': 'they rapidly faded or changed color', 'answer_start': 359},
#  {'text': 'Campus Martius Park', 'answer_start': 224},
#  {'text': 'the Abyssinian Emperor', 'answer_start': 405},
#  {'text': 'Mega Drive', 'answer_start': 151},
#  {'text': 'radicals', 'answer_start': 668},
#  {'text': '1919–22', 'answer_start': 832},
#  {'text': 'bureaucracy', 'answer_start': 271},
#  {'text': 'worries of injuries to players, along with travel issues',
#   'answer_start': 128},
#  {'text': 'hard drive', 'answer_start': 983},
#  {'text': 'West German engineers', 'answer_start': 217},
#  {'text': 'Chief of Staff of the Army', 'answer_start': 302},
#  {'text': 'two main parts', 'answer_start': 300},
#  {'text': 'Chicago Daily News', 'answer_start': 203},
#  {'text': '10%', 'answer_start': 85},
#  {'text': 'Gertrude Stein', 'answer_start': 289},
#  {'text': 'monophonic', 'answer_start': 114},
#  {'text': '1978', 'answer_start': 448},
#  {'text': 'voltage spike to temporarily disable the 10NES chip',
#   'answer_start': 205},
#  {'text': 'mutilation', 'answer_start': 432},
#  {'text': '1795', 'answer_start': 3},
#  {'text': 'Cretaceous', 'answer_start': 919},
#  {'text': 'Mont Pèlerin Society', 'answer_start': 633},
#  {'text': 'about 100,000', 'answer_start': 551},
#  {'text': 'the Association to Advance Collegiate Schools of Business',
#   'answer_start': 136},
#  {'text': 'carvings', 'answer_start': 87},
#  {'text': 'Eighth', 'answer_start': 469},
#  {'text': 'vocabulary', 'answer_start': 34},
#  {'text': 'Peloponnese and Asia Minor', 'answer_start': 257},
#  {'text': 'decline of Constantinople', 'answer_start': 4},
#  {'text': 'the type of transistor', 'answer_start': 308},
#  {'text': 'independence', 'answer_start': 689},
#  {'text': "electronic warfare and the protection of the Armed Forces' communications and computer networks",
#   'answer_start': 87},
#  {'text': '9 meters', 'answer_start': 577},
#  {'text': 'four', 'answer_start': 79},
#  {'text': 'wild cereals', 'answer_start': 242},
#  {'text': 'hydrogen', 'answer_start': 88},
#  {'text': 'The Ghoomar dance', 'answer_start': 0},
#  {'text': 'the ways in which scientists work', 'answer_start': 236},
#  {'text': '1175', 'answer_start': 393},
#  {'text': 'Great Explainer', 'answer_start': 29},
#  {'text': 'Coinage Act of 1792', 'answer_start': 67},
#  {'text': 'movie posters', 'answer_start': 503},
#  {'text': 'many Greeks sought better employment and education opportunities by leaving for the West',
#   'answer_start': 53},
#  {'text': 'Germany', 'answer_start': 375},
#  {'text': 'pace of reforms were uneven and ultimately proved insufficient',
#   'answer_start': 459},
#  {'text': 'the Liberal and National parties', 'answer_start': 342},
#  {'text': 'daimyo', 'answer_start': 66},
#  {'text': '$900 million', 'answer_start': 906},
#  {'text': '2012', 'answer_start': 693},
#  {'text': 'Harris County', 'answer_start': 377},
#  {'text': 'institutional architecture', 'answer_start': 343},
#  {'text': 'LD-700', 'answer_start': 90},
#  {'text': 'mRNA is translated to protein', 'answer_start': 206},
#  {'text': 'a codec (coder/decoder)', 'answer_start': 180},
#  {'text': '1852', 'answer_start': 480},
#  {'text': 'mats and fans', 'answer_start': 224},
#  {'text': 'primordial, natural, enduring and distinct', 'answer_start': 238},
#  {'text': 'The collapse of that system and the aligning of France with Austria and of Great Britain with Prussia constituted what is known as the “diplomatic revolution”',
#   'answer_start': 871},
#  {'text': 'more expensive, so its use is limited to smaller lamps',
#   'answer_start': 542},
#  {'text': '17 October 1807', 'answer_start': 110},
#  {'text': 'Roman Empire', 'answer_start': 316},
#  {'text': 'lender-of-last-resort', 'answer_start': 549},
#  {'text': 'filter bank', 'answer_start': 118},
#  {'text': 'Interstate 10', 'answer_start': 26},
#  {'text': 'three years old', 'answer_start': 324},
#  {'text': 'around 140 years ago', 'answer_start': 752},
#  {'text': 'Double leg work', 'answer_start': 179},
#  {'text': 'seeing the source code', 'answer_start': 138},
#  {'text': 'Sudanese Arabs', 'answer_start': 217},
#  {'text': 'Central Africa', 'answer_start': 169},
#  {'text': 'the method was tending to produce bipartite stemmas regardless of the actual history of the witnesses.',
#   'answer_start': 387},
#  {'text': 'Edward VII', 'answer_start': 178},
#  {'text': '1996', 'answer_start': 690},
#  {'text': 'signature of the clerk is omitted, as is the Norman French formula',
#   'answer_start': 500},
#  {'text': 'Boston', 'answer_start': 219},
#  {'text': 'guitar', 'answer_start': 340},
#  {'text': 'Israeli Basketball Super League', 'answer_start': 162},
#  {'text': 'Henry VIII', 'answer_start': 833},
#  {'text': 'boats', 'answer_start': 162},
#  {'text': 'President Franklin D. Roosevelt', 'answer_start': 363},
#  {'text': '59 to 41.', 'answer_start': 727},
#  {'text': 'third-party software developers', 'answer_start': 334},
#  {'text': "identifying a subject's object of attraction without attributing a sex assignment or gender identity to the subject",
#   'answer_start': 201},
#  {'text': 'Joe Anderson', 'answer_start': 424},
#  {'text': 'May 3', 'answer_start': 39},
#  {'text': 'Rev-ErbA alpha clock', 'answer_start': 258},
#  {'text': 'President Truman', 'answer_start': 52},
#  {'text': 'the court', 'answer_start': 384},
#  {'text': '150', 'answer_start': 26},
#  {'text': 'John Locke', 'answer_start': 498},
#  {'text': 'Laurentian Highlands', 'answer_start': 4},
#  {'text': '1784', 'answer_start': 497},
#  {'text': '1995', 'answer_start': 847},
#  {'text': 'the Earth', 'answer_start': 348},
#  {'text': 'ancestry', 'answer_start': 395},
#  {'text': 'AC current', 'answer_start': 223},
#  {'text': 'color', 'answer_start': 194},
#  {'text': 'Jordan of Saxony', 'answer_start': 443},
#  {'text': '40', 'answer_start': 518},
#  {'text': 'Julian Fontana', 'answer_start': 259},
#  {'text': 'Good Water Store and Café', 'answer_start': 351},
#  {'text': '6 September 2007', 'answer_start': 188},
#  {'text': 'marked bike routes, signal crossings, on-street bike lanes, mountain-biking trails, and dedicated shared-use paths',
#   'answer_start': 126},
#  {'text': '18 August', 'answer_start': 3},
#  {'text': 'goes far beyond its legal obligations', 'answer_start': 419},
#  {'text': 'foreign correspondents', 'answer_start': 230},
#  {'text': 'Outdoor Life Network', 'answer_start': 422},
#  {'text': 'German', 'answer_start': 258},
#  {'text': 'balance', 'answer_start': 221},
#  {'text': '150,000', 'answer_start': 184},
#  {'text': 'NTFS', 'answer_start': 4},
#  {'text': 'Buddha', 'answer_start': 210},
#  {'text': 'Phillies', 'answer_start': 154},
#  {'text': 'about 1.3 billion', 'answer_start': 1038},
#  {'text': 'Xerox PARC', 'answer_start': 770},
#  {'text': 'pronounced rise in crime in the years following World War II',
#   'answer_start': 58},
#  {'text': '11–12 segments', 'answer_start': 76},
#  {'text': 'petroleum', 'answer_start': 65},
#  {'text': 'Prelate; the Dean; the Secretary; the Registrar; the King of Arms; and the Usher',
#   'answer_start': 33},
#  {'text': 'Ron Jaworski', 'answer_start': 202},
#  {'text': 'Leadenhall Street', 'answer_start': 236},
#  {'text': '1997', 'answer_start': 3},
#  {'text': '1890', 'answer_start': 3},
#  {'text': 'Admiral Nakhimov', 'answer_start': 271},
#  {'text': 'Voting Rights Act of 1965', 'answer_start': 126},
#  {'text': 'greatly extended the area of the country', 'answer_start': 289},
#  {'text': 'four', 'answer_start': 683},
#  {'text': '1949', 'answer_start': 317},
#  {'text': 'individual worth', 'answer_start': 168},
#  {'text': '182', 'answer_start': 289},
#  {'text': 'April 606', 'answer_start': 329},
#  {'text': 'Andrus Ansip', 'answer_start': 409},
#  {'text': '1854', 'answer_start': 59},
#  {'text': 'equilibrium line', 'answer_start': 157},
#  {'text': 'seven', 'answer_start': 20},
#  {'text': 'Westchester', 'answer_start': 451},
#  {'text': 'ecstatic worship', 'answer_start': 472},
#  {'text': 'Venice', 'answer_start': 486},
#  {'text': 'the Pope', 'answer_start': 511},
#  {'text': 'Their grant-making focus has been since 2011 on sanitation science and technology ("transformative technologies")',
#   'answer_start': 267},
#  {'text': '1774', 'answer_start': 82},
#  {'text': 'numerous explanatory notes giving her own answers to doubts that Darwin expressed',
#   'answer_start': 1350},
#  {'text': 'East Francia', 'answer_start': 371},
#  {'text': '1845', 'answer_start': 145},
#  {'text': 'confessions of faith', 'answer_start': 167},
#  {'text': 'Switzerland', 'answer_start': 479},
#  {'text': 'only one', 'answer_start': 299},
#  {'text': 'August 1855', 'answer_start': 3},
#  {'text': '1988', 'answer_start': 801},
#  {'text': 'provide a legal definition of the crime', 'answer_start': 400},
#  {'text': 'German courts', 'answer_start': 600},
#  {'text': 'Ismail Hakki Bursevi', 'answer_start': 1438},
#  {'text': 'repression of memories where a person moves an unbearable memory to the unconscious mind',
#   'answer_start': 613},
#  {'text': 'honorary special membership', 'answer_start': 675},
#  {'text': 'Rhode Island', 'answer_start': 113},
#  {'text': '2001', 'answer_start': 199},
#  {'text': 'lower efficiency', 'answer_start': 421},
#  {'text': 'Puerto Ricans may enlist in the U.S. military.',
#   'answer_start': 479},
#  {'text': 'Palais de Justice', 'answer_start': 169},
#  {'text': 'three petabytes', 'answer_start': 64},
#  {'text': 'continuously added more preconditions to its ratification',
#   'answer_start': 658},
#  {'text': 'a genuine cry', 'answer_start': 721},
#  {'text': 'President of the Church (currently Thomas S. Monson)',
#   'answer_start': 135},
#  {'text': 'kinship', 'answer_start': 98},
#  {'text': 'the colors of the Russian flag', 'answer_start': 147},
#  {'text': 'the Cleveland Indians', 'answer_start': 250},
#  {'text': 'legislative branch', 'answer_start': 378},
#  {'text': 'Afro-Brazilians', 'answer_start': 755},
#  {'text': 'South Africa', 'answer_start': 85},
#  {'text': 'turn to maritime trades', 'answer_start': 432},
#  {'text': 'the hydrogen bomb', 'answer_start': 605},
#  {'text': 'racial categories', 'answer_start': 728},
#  {'text': 'to withstand the pressure of the ventricular constriction',
#   'answer_start': 302},
#  {'text': '1957', 'answer_start': 152},
#  {'text': '393', 'answer_start': 738},
#  {'text': 'Żelazowa Wola', 'answer_start': 28},
#  {'text': 'the same way', 'answer_start': 428},
#  {'text': '20 September 1582', 'answer_start': 514},
#  {'text': 'provided the stylus, record player, and record itself are built to withstand it',
#   'answer_start': 613},
#  {'text': 'major news and media', 'answer_start': 384},
#  {'text': 'rise', 'answer_start': 176},
#  {'text': 'dosa', 'answer_start': 405},
#  {'text': '19', 'answer_start': 659},
#  {'text': 'iCloud cloud service', 'answer_start': 281},
#  {'text': 'Metro-style apps', 'answer_start': 188},
#  {'text': 'Archimedes', 'answer_start': 641},
#  {'text': 'record of anti-government protest', 'answer_start': 96},
#  {'text': 'January 3, 1959', 'answer_start': 553},
#  {'text': '2012', 'answer_start': 720},
#  {'text': 'because the era was dominated by questions of foreign and military policy',
#   'answer_start': 425},
#  {'text': 'exempted the entire class from all but one tax',
#   'answer_start': 259},
#  {'text': 'Duke of Wellington', 'answer_start': 88},
#  {'text': 'plague', 'answer_start': 496},
#  {'text': 'the Orthodox Church', 'answer_start': 901},
#  {'text': '70%', 'answer_start': 163},
#  {'text': 'the top 10 to 15 in the nation', 'answer_start': 213},
#  {'text': 'College of Charleston', 'answer_start': 787},
#  {'text': 'Shaye J. D. Cohen', 'answer_start': 23},
#  {'text': 'cancer pain', 'answer_start': 1040},
#  {'text': '1378', 'answer_start': 630},
#  {'text': 'Between 750 and 1,000', 'answer_start': 919},
#  {'text': 'Arian', 'answer_start': 514},
#  {'text': 'low', 'answer_start': 486},
#  {'text': 'Hubbell', 'answer_start': 243},
#  {'text': 'Achaemenid Persians', 'answer_start': 24},
#  {'text': 'Humira', 'answer_start': 103},
#  {'text': 'the southern end of the Zagros Mountains,', 'answer_start': 552},
#  {'text': 'with the emergence of iron-working settlements in an area south of present-day Mandalay',
#   'answer_start': 336},
#  {'text': 'Punjabi', 'answer_start': 54},
#  {'text': 'Jane Stirling', 'answer_start': 208},
#  {'text': 'Shax', 'answer_start': 103},
#  {'text': 'Wilmsen', 'answer_start': 68},
#  {'text': 'Savages', 'answer_start': 999},
#  {'text': 'microscopic features', 'answer_start': 283},
#  {'text': 'tabular method', 'answer_start': 652},
#  {'text': 'Only the high-field value Γ′p-90(hi) is of interest in determining the Planck constant',
#   'answer_start': 483},
#  {'text': 'June 1861', 'answer_start': 136},
#  {'text': 'Servius and Donatus', 'answer_start': 180},
#  {'text': 'Pompey the Great', 'answer_start': 585},
#  {'text': 'the Taipei Fire Department', 'answer_start': 37},
#  {'text': 'Veronal', 'answer_start': 326},
#  {'text': 'the Tibetan government in exile', 'answer_start': 520},
#  {'text': 'quarterback or punter', 'answer_start': 356},
#  {'text': 'over four million', 'answer_start': 726},
#  {'text': 'lead singer', 'answer_start': 153},
#  {'text': 'High German', 'answer_start': 351},
#  {'text': '1904 to 1907', 'answer_start': 5},
#  {'text': 'minute', 'answer_start': 596},
#  {'text': 'Foreign Direct Investment', 'answer_start': 291},
#  {'text': 'discordance', 'answer_start': 896},
#  {'text': 'children helping run the family business.', 'answer_start': 734},
#  {'text': 'extremely', 'answer_start': 137},
#  {'text': 'worldwide', 'answer_start': 56},
#  {'text': 'This Is My Now', 'answer_start': 262},
#  {'text': 'England', 'answer_start': 422},
#  {'text': 'Mark Dibben', 'answer_start': 507},
#  {'text': 'king Krishnadevaraya', 'answer_start': 581},
#  {'text': 'Roman country villas', 'answer_start': 188},
#  {'text': 'PN2222A', 'answer_start': 358},
#  {'text': 'five', 'answer_start': 295},
#  {'text': 'seed-producing plants', 'answer_start': 186},
#  {'text': 'January 1941', 'answer_start': 489},
#  {'text': 'around 1919', 'answer_start': 572},
#  {'text': 'Echiura and Sipuncula', 'answer_start': 276},
#  {'text': 'Thomas Young', 'answer_start': 9},
#  {'text': 'atomic bombings of Hiroshima and Nagasaki', 'answer_start': 204},
#  {'text': 'Umhlanga Reed Dance.', 'answer_start': 57},
#  {'text': 'January 16, 2007', 'answer_start': 29},
#  {'text': 'his ring', 'answer_start': 333},
#  {'text': 'large townships located away from the cities', 'answer_start': 308},
#  {'text': 'iconographic', 'answer_start': 334},
#  {'text': 'The common practice period', 'answer_start': 0},
#  {'text': 'Bantu, Khoisan, and European descent', 'answer_start': 558},
#  {'text': 'one God in three persons', 'answer_start': 338},
#  {'text': 'providing it with information it gathers, receiving information from military intelligence organizations, and cooperating on field activities',
#   'answer_start': 56},
#  {'text': 'Deputy Chief of the Defence Staff (Capability), Deputy CDS (Personnel and Training) and Deputy CDS (Operations)',
#   'answer_start': 80},
#  {'text': 'three', 'answer_start': 239},
#  {'text': 'tonalities', 'answer_start': 326},
#  {'text': 'Brazilian jiu-jitsu, Karate, Muay Thai and Taekwondo',
#   'answer_start': 157},
#  {'text': 'Gothic', 'answer_start': 69},
#  {'text': '50', 'answer_start': 470},
#  {'text': 'Treaty of Küçük Kaynarca', 'answer_start': 303},
#  {'text': 'Brick', 'answer_start': 86},
#  {'text': 'English', 'answer_start': 396},
#  {'text': 'Javier Glickman', 'answer_start': 1532},
#  {'text': 'four-year', 'answer_start': 45},
#  {'text': "an 'authentic interpretation'", 'answer_start': 465},
#  {'text': 'Palenque', 'answer_start': 681},
#  {'text': 'in the subcode', 'answer_start': 76},
#  {'text': 'extent of sexual attractions toward members of the other, same, both sexes or neither',
#   'answer_start': 212},
#  {'text': 'the Anglican Communion', 'answer_start': 18},
#  {'text': 'Faculty of Medicine', 'answer_start': 418},
#  {'text': '1814', 'answer_start': 3},
#  {'text': 'high-tech weapons systems', 'answer_start': 40},
#  {'text': 'Wakamatsu', 'answer_start': 340},
#  {'text': 'The farmer', 'answer_start': 0},
#  {'text': 'As of the 2010–11 season, the Premier League introduced new rules mandating that each club must register a maximum 25-man squad of players aged over 21,',
#   'answer_start': 345},
#  {'text': 'while Muammar attended secondary school, something neither parent had done.',
#   'answer_start': 683},
#  {'text': 'Scotland', 'answer_start': 169},
#  {'text': 'Democrats', 'answer_start': 377},
#  {'text': 'hydrocracking', 'answer_start': 289},
#  {'text': 'Occitan, Flemish, and Basque', 'answer_start': 224},
#  {'text': 'America First Committee', 'answer_start': 54},
#  {'text': 'schools', 'answer_start': 296},
#  {'text': 'every', 'answer_start': 229},
#  {'text': 'May 14, 1973', 'answer_start': 63},
#  {'text': 'Buddhism and Zen, and to a lesser extent Confucianism and Shinto',
#   'answer_start': 20},
#  {'text': '60 or older', 'answer_start': 227},
#  {'text': 'Lebanon', 'answer_start': 349},
#  {'text': 'fully asphalted (throughout their entire length)',
#   'answer_start': 587},
#  {'text': 'Anglican', 'answer_start': 131},
#  {'text': 'four', 'answer_start': 249},
#  {'text': 'three', 'answer_start': 142},
#  {'text': '1923', 'answer_start': 751},
#  {'text': '40', 'answer_start': 223},
#  {'text': 'nunataks', 'answer_start': 170},
#  {'text': 'private wealth', 'answer_start': 596},
#  {'text': '1815', 'answer_start': 9},
#  {'text': 'the sovereignty or rule of God in all things', 'answer_start': 493},
#  {'text': 'once', 'answer_start': 837},
#  {'text': 'forbidden', 'answer_start': 387},
#  {'text': 'Bath School of Pharmacy (founded 1907', 'answer_start': 249},
#  {'text': '6', 'answer_start': 134},
#  {'text': 'alcohol dehydrogenase', 'answer_start': 489},
#  {'text': '1900', 'answer_start': 85},
#  {'text': '"black" or "white"', 'answer_start': 770},
#  {'text': '2010', 'answer_start': 4},
#  {'text': 'Benjamin Franklin and Thomas Jefferson', 'answer_start': 608},
#  {'text': 'the consequent nature', 'answer_start': 604},
#  {'text': 'Iberian peninsula', 'answer_start': 102},
#  {'text': 'rational analysis', 'answer_start': 788},
#  {'text': 'all lower Courts', 'answer_start': 302},
#  {'text': 'Pacific Islands University', 'answer_start': 274},
#  {'text': 'Northwestern University', 'answer_start': 112},
#  {'text': 'tenth', 'answer_start': 59},
#  {'text': '2012', 'answer_start': 253},
#  {'text': 'men of Greek origin made up a significant proportion of the Ottoman army, navy',
#   'answer_start': 892},
#  {'text': 'Data compression', 'answer_start': 0},
#  {'text': 'Soviet Union', 'answer_start': 461},
#  {'text': 'technological advancements', 'answer_start': 607},
#  {'text': 'Fat Tuesday', 'answer_start': 58},
#  {'text': 'traditional English spelling', 'answer_start': 531},
#  {'text': 'k', 'answer_start': 276},
#  {'text': 'some jurisdictions require the permit to be displayed in the elevator cab, other jurisdictions allow for the operating permit to be kept on file elsewhere',
#   'answer_start': 118},
#  {'text': 'Emancipation Proclamation', 'answer_start': 9},
#  {'text': 'Spider-Man', 'answer_start': 199},
#  {'text': 'CVP', 'answer_start': 150},
#  {'text': 'Frank Stilwell', 'answer_start': 996},
#  {'text': 'controversial', 'answer_start': 936},
#  {'text': 'Melburnians', 'answer_start': 720},
#  {'text': 'Krull topology', 'answer_start': 286},
#  {'text': 'May 24, 2007', 'answer_start': 355},
#  {'text': 'bishops', 'answer_start': 265},
#  {'text': 'General', 'answer_start': 488},
#  {'text': 'Government of India Act 1935', 'answer_start': 539},
#  {'text': '305', 'answer_start': 367},
#  {'text': 'using visual alphabets.', 'answer_start': 270},
#  {'text': 'chemical engineer', 'answer_start': 292},
#  {'text': 'High-definition image sources', 'answer_start': 0},
#  {'text': 'FDR Drive', 'answer_start': 22},
#  {'text': 'Bachelor of Canon Law', 'answer_start': 337},
#  {'text': 'industry dispersal may have been a factor', 'answer_start': 297},
#  {'text': 'Sega of America', 'answer_start': 401},
#  {'text': 'Paleozoic groups', 'answer_start': 114},
#  {'text': '1514', 'answer_start': 124},
#  {'text': 'March 2012', 'answer_start': 262},
#  {'text': 'government officials', 'answer_start': 34},
#  {'text': 'music, dance and art', 'answer_start': 341},
#  {'text': 'Life on Earth, The Private Life of Plants, The Blue Planet, The Life of Mammals, Planet Earth and Frozen Planet',
#   'answer_start': 266},
#  {'text': 'Hudson Bay.', 'answer_start': 583},
#  {'text': 'Buddhism', 'answer_start': 67},
#  {'text': 'Chinese commanders', 'answer_start': 182},
#  {'text': 'six', 'answer_start': 77},
#  {'text': 'positively', 'answer_start': 307},
#  {'text': 'The Guardian Council', 'answer_start': 0},
#  {'text': 'bombers should strike a single target each night and use more incendiaries because they had a greater impact on production than high explosives',
#   'answer_start': 181},
#  {'text': 'Engels', 'answer_start': 332},
#  {'text': 'by garroting', 'answer_start': 198},
#  {'text': 'United States', 'answer_start': 7},
#  {'text': 'In the 1970s the Royal Portbury Dock was constructed to provide extra capacity for the Port of Bristol',
#   'answer_start': 476},
#  {'text': 'large', 'answer_start': 163},
#  {'text': 'late sixteenth century', 'answer_start': 237},
#  {'text': '1982', 'answer_start': 321},
#  {'text': 'typically emerge between middle childhood and early adolescence',
#   'answer_start': 423},
#  {'text': 'Maurya Empire', 'answer_start': 46},
#  {'text': 'the rising of Joseon Dynasty to the enthronement of King Gojong',
#   'answer_start': 198},
#  {'text': '4,000 to 5,000 years ago', 'answer_start': 269},
#  {'text': 'Jim Crow', 'answer_start': 160},
#  {'text': 'measurement of camera output that had lossy compression',
#   'answer_start': 317},
#  {'text': 'temperature', 'answer_start': 267},
#  {'text': '10', 'answer_start': 14},
#  {'text': 'Army', 'answer_start': 494},
#  {'text': 'technical', 'answer_start': 197},
#  {'text': 'Descartes', 'answer_start': 201},
#  {'text': 'Missouri river', 'answer_start': 346},
#  {'text': 'chemicals', 'answer_start': 723},
#  {'text': 'April 1, 1937', 'answer_start': 347},
#  {'text': '17 September', 'answer_start': 76},
#  {'text': 'Whittle W.1', 'answer_start': 560},
#  {'text': '1743', 'answer_start': 452},
#  {'text': 'Apia', 'answer_start': 363},
#  {'text': 'Arabic poetry and Persian poetry', 'answer_start': 20},
#  {'text': 'Essential Air Service program', 'answer_start': 186},
#  {'text': 'animal sacrifices', 'answer_start': 454},
#  {'text': 'the Queen on the advice of the British Government.',
#   'answer_start': 133},
#  {'text': 'Second Avenue', 'answer_start': 42},
#  {'text': '20th century and contemporary art', 'answer_start': 56},
#  {'text': 'Venetian-styled', 'answer_start': 738},
#  {'text': 'Joan Gustafson', 'answer_start': 47},
#  {'text': 'spruce', 'answer_start': 144},
#  {'text': 'German and English', 'answer_start': 46},
#  {'text': 'inverse', 'answer_start': 232},
#  {'text': "'07", 'answer_start': 252},
#  {'text': 'Germany', 'answer_start': 144},
#  {'text': 'an identity they can live with', 'answer_start': 1021},
#  {'text': 'Guinea-Bissau', 'answer_start': 0},
#  {'text': '51', 'answer_start': 517},
#  {'text': 'Manchester', 'answer_start': 941},
#  {'text': 'Chinese students', 'answer_start': 435},
#  {'text': 'honorary degrees', 'answer_start': 155},
#  {'text': "Marie de' Medici", 'answer_start': 362},
#  {'text': 'bit reservoir', 'answer_start': 32},
#  {'text': '1858', 'answer_start': 467},
#  {'text': 'when an organism successfully enters the body, grows and multiplies.',
#   'answer_start': 17},
#  {'text': 'Chris Corbould', 'answer_start': 367},
#  {'text': 'sound', 'answer_start': 91},
#  {'text': '40 percent', 'answer_start': 146},
#  {'text': 'June 8, 1854', 'answer_start': 91},
#  {'text': 'data compression', 'answer_start': 493},
#  {'text': '59', 'answer_start': 297},
#  {'text': 'the universe', 'answer_start': 133},
#  {'text': 'Kris Allen', 'answer_start': 23},
#  {'text': '15-pin expansion port', 'answer_start': 549},
#  {'text': 'judiciary', 'answer_start': 247},
#  {'text': 'Sense without Matter', 'answer_start': 61},
#  {'text': 'Joseph', 'answer_start': 434},
#  {'text': 'modulus of rupture', 'answer_start': 163},
#  {'text': '1,600', 'answer_start': 197},
#  {'text': 'C', 'answer_start': 67},
#  {'text': "Mexico's Yucatan Peninsula", 'answer_start': 291},
#  {'text': 'Chief Wildlife Warden', 'answer_start': 278},
#  {'text': 'ANZUS Treaty', 'answer_start': 247},
#  {'text': 'two-year', 'answer_start': 172},
#  {'text': 'Atlantic Archipelago', 'answer_start': 333},
#  {'text': 'Maycomb, Alabama', 'answer_start': 112},
#  {'text': 'bicycle', 'answer_start': 18},
#  {'text': 'August 30, 1955', 'answer_start': 902},
#  {'text': '17 million', 'answer_start': 116},
#  {'text': 'gradually changed', 'answer_start': 69},
#  {'text': 'Miami', 'answer_start': 392},
#  {'text': '1952', 'answer_start': 285},
#  {'text': 'to get reinforcements', 'answer_start': 687},
#  {'text': '7th', 'answer_start': 156},
#  {'text': 'Native Americans', 'answer_start': 629},
#  {'text': "Queen's Gallery", 'answer_start': 374},
#  {'text': 'minority religious groups undermine national unity',
#   'answer_start': 137},
#  {'text': 'QUEL', 'answer_start': 480},
#  {'text': 'domestic dog', 'answer_start': 920},
#  {'text': 'the "upper" 128 characters for the Greek alphabet',
#   'answer_start': 230},
#  {'text': 'Devonport High School for Girls', 'answer_start': 143},
#  {'text': '12,000 years ago', 'answer_start': 256},
#  {'text': 'village near Anyang in Henan Province', 'answer_start': 387},
#  {'text': 'about the 5th century', 'answer_start': 292},
#  {'text': 'Spanish and Portuguese', 'answer_start': 242},
#  {'text': 'the sickness of the euro', 'answer_start': 499},
#  {'text': 'March 28, 1969', 'answer_start': 18},
#  {'text': 'Islamic institutions', 'answer_start': 74},
#  {'text': 'the Colloquy of Marburg', 'answer_start': 590},
#  {'text': 'Air Force Officer Training School', 'answer_start': 224},
#  {'text': '450 yuan', 'answer_start': 153},
#  {'text': 'stimulate the economy', 'answer_start': 498},
#  {'text': 'perfect', 'answer_start': 97},
#  {'text': 'extensive actions to reduce the number of children working, and to focus on the importance of facilitating the proper growth and development of children.',
#   'answer_start': 387},
#  {'text': 'Santiago de Compostela', 'answer_start': 15},
#  {'text': 'Lithuania', 'answer_start': 109},
#  {'text': 'U.S. News & World Report', 'answer_start': 122},
#  {'text': 'their cars always move synchronously in opposite directions,',
#   'answer_start': 717},
#  {'text': 'the columns may be painted red', 'answer_start': 242},
#  {'text': '7th century', 'answer_start': 130},
#  {'text': 'dominated environments', 'answer_start': 463},
#  {'text': 'Helsinki-86', 'answer_start': 301},
#  {'text': 'a well constructed family', 'answer_start': 512},
#  {'text': 'Computer security', 'answer_start': 0},
#  {'text': 'more affordable housing and cost of living', 'answer_start': 679},
#  {'text': 'Op. 10 Études', 'answer_start': 422},
#  {'text': 'a research project', 'answer_start': 287},
#  {'text': 'Parthian', 'answer_start': 359},
#  {'text': 'lines of crescent-shape depressions in the rock underlying a glacier',
#   'answer_start': 316},
#  {'text': 'a revolution', 'answer_start': 498},
#  {'text': '12', 'answer_start': 55},
#  {'text': 'the need for bomb-proof shelters.', 'answer_start': 96},
#  {'text': 'Belgrade', 'answer_start': 36},
#  {'text': '20,000', 'answer_start': 176},
#  {'text': "1924 Rietveld Schröder House, which is listed on UNESCO's world heritage sites",
#   'answer_start': 575},
#  {'text': 'DesignIntelligence', 'answer_start': 25},
#  {'text': 'Rs.1,16,886', 'answer_start': 438},
#  {'text': '"rural districts"', 'answer_start': 146},
#  {'text': 'a humid subtropical climate', 'answer_start': 12},
#  {'text': 'dukkōn', 'answer_start': 244},
#  {'text': '5 August 25', 'answer_start': 64},
#  {'text': 'does not communicate', 'answer_start': 686},
#  {'text': 'not useful for every use, since legacy encodings have used multiple characteristics per single code point',
#   'answer_start': 219},
#  {'text': 'The Tatler and The Spectator', 'answer_start': 1127},
#  {'text': 'the "Good Pope"', 'answer_start': 1268},
#  {'text': 'photo-receptive cells in', 'answer_start': 915},
#  {'text': 'basic', 'answer_start': 279},
#  {'text': '1505–1521', 'answer_start': 24},
#  {'text': 'four', 'answer_start': 104},
#  {'text': 'great-great-grandmother', 'answer_start': 24},
#  {'text': 'the ONE Campaign', 'answer_start': 44},
#  {'text': 'Latin Church and Eastern Catholic Churches', 'answer_start': 248},
#  {'text': '12.8%', 'answer_start': 316},
#  {'text': 'Oligocene', 'answer_start': 405},
#  {'text': 'ninth', 'answer_start': 645},
#  {'text': "St. George's", 'answer_start': 668},
#  {'text': 'male', 'answer_start': 582},
#  {'text': 'silk', 'answer_start': 179},
#  {'text': '$2.3 billion', 'answer_start': 597},
#  {'text': 'Mswati II. KaNgwane', 'answer_start': 51},
#  {'text': 'Hangzhou', 'answer_start': 319},
#  {'text': 'Oklahoma City', 'answer_start': 70},
#  {'text': 'Glencoe and Sea Nymph', 'answer_start': 343},
#  {'text': 'removal of the gaseous protoplanetary disc', 'answer_start': 164},
#  {'text': 'white', 'answer_start': 371},
#  {'text': '1.44 terajoules (400,000 kWh)', 'answer_start': 664},
#  {'text': 'attacks on government offices', 'answer_start': 121},
#  {'text': '1907', 'answer_start': 139},
#  {'text': 'servitude and bondage', 'answer_start': 129},
#  {'text': 'March 2012', 'answer_start': 3},
#  {'text': 'an added prefix', 'answer_start': 123},
#  {'text': 'golden age', 'answer_start': 889},
#  {'text': 'National Academy of Medical Sciences', 'answer_start': 377},
#  {'text': '1615', 'answer_start': 276},
#  {'text': '1930', 'answer_start': 34},
#  {'text': 'The Geophysics Institute', 'answer_start': 131},
#  {'text': 'Russo-Turkish War', 'answer_start': 135},
#  {'text': 'stilb', 'answer_start': 918},
#  {'text': 'Because more Americans have insisted on being allowed to acknowledge their mixed racial origins',
#   'answer_start': 618},
#  {'text': 'Prussia', 'answer_start': 206},
#  {'text': 'in the 1960s', 'answer_start': 619},
#  {'text': '2012', 'answer_start': 23},
#  {'text': 'earthwork', 'answer_start': 145},
#  {'text': "northeast and on the city's fringes", 'answer_start': 208},
#  {'text': 'East Coast Greenway', 'answer_start': 461},
#  {'text': 'decentralised structure', 'answer_start': 145},
#  {'text': 'gap', 'answer_start': 270},
#  {'text': 'William Hung', 'answer_start': 117},
#  {'text': 'Byzantine', 'answer_start': 178},
#  {'text': '1660', 'answer_start': 400},
#  {'text': 'clitellates', 'answer_start': 12},
#  {'text': 'iPods', 'answer_start': 0},
#  {'text': 'Chengdu Shuangliu International Airport', 'answer_start': 320},
#  {'text': 'March 2008', 'answer_start': 290},
#  {'text': 'concert', 'answer_start': 155},
#  {'text': '1990', 'answer_start': 288},
#  {'text': '185 million', 'answer_start': 278},
#  {'text': 'including Martin Luther King, Jr.', 'answer_start': 238},
#  {'text': '35th', 'answer_start': 41},
#  {'text': 'Athanasius', 'answer_start': 484},
#  {'text': 'vendors would be required to provide means for users to re-configure or disable secure boot',
#   'answer_start': 822},
#  {'text': 'Washington, D.C.', 'answer_start': 298},
#  {'text': 'Harrington Grove, Springdale, Dominion Park', 'answer_start': 377},
#  {'text': 'the Austrians, under the command of General Laudon, captured Glatz',
#   'answer_start': 14},
#  {'text': 'approximated to the closest three-hour period',
#   'answer_start': 665},
#  {'text': 'Eisenhower', 'answer_start': 359},
#  {'text': 'private vehicle', 'answer_start': 548},
#  {'text': 'stools', 'answer_start': 426},
#  {'text': 'downtown core', 'answer_start': 413},
#  {'text': 'Texas', 'answer_start': 650},
#  {'text': 'Victor Lardent', 'answer_start': 70},
#  {'text': 'guiding legislation favored by his party through the House, or in resisting those programs of the other party that are considered undesirable by his own party',
#   'answer_start': 162},
#  {'text': 'Andaman Sea to the southwest and the south, which forms one quarter of its total perimeter.',
#   'answer_start': 427},
#  {'text': 'Vision Quest', 'answer_start': 105},
#  {'text': 'A bantam', 'answer_start': 0},
#  {'text': '1997', 'answer_start': 226},
#  {'text': '22 July 2010', 'answer_start': 3},
#  {'text': 'National Park Service', 'answer_start': 95},
#  {'text': 'Jesus Christ, the Savior of the human race.', 'answer_start': 368},
#  {'text': 'Kann Margit', 'answer_start': 641},
#  {'text': 'the United Kingdom and France', 'answer_start': 258},
#  {'text': '£12 million', 'answer_start': 46},
#  {'text': 'Raleigh also has two alternative high schools.',
#   'answer_start': 471},
#  {'text': '20%', 'answer_start': 713},
#  {'text': 'one-half', 'answer_start': 556},
#  {'text': 'humans.', 'answer_start': 320},
#  {'text': 'the hands may not have been able to support the weight',
#   'answer_start': 102},
#  {'text': 'the mid-19th century', 'answer_start': 84},
#  {'text': 'trans fats', 'answer_start': 176},
#  {'text': '2.60', 'answer_start': 195},
#  ...]

# %%
# Save the slow pretrained tokenizer
slow_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
save_path = "bert_base_uncased/"
if not os.path.exists(save_path):
    os.makedirs(save_path)
slow_tokenizer.save_pretrained(save_path)

tokenizer = BertWordPieceTokenizer("bert_base_uncased/vocab.txt", lowercase=True)

# %%
def ds():
    a=1+2
    return a
# Out:
# 3

# %%
def get_model_inputs(context,answer,questions):
    dataset_dict = {
        "input_ids": [],
        "token_type_ids": [],
        "attention_mask": [],
        "start_token_idx": [],
        "end_token_idx": []}
    mp=0
    #print(dataset_dict)
    for con, ans,ques in zip(context,answer,questions):
        #print(dataset_dict)
        skip=False
        #preprocess answers
        start_char_idx=ans['answer_start']
        end_char_idx=start_char_idx+len(ans['text'])
        if end_char_idx>= len(context): ##the context passage is being cut off  , skip this data 
            skip=True
            #return
        char_in_ans=[0]*len(con) ## initialize all char in context to be 0
        for i in range(start_char_idx,end_char_idx):
                char_in_ans[i]=1                     ##mark all the answer char idx as 1
        ##tokenize context
        tokenized_context = tokenizer.encode(con) 
        ans_token_idx=[]
        for j , (start,end) in enumerate(tokenized_context.offsets): ## find all token(word) index in answers
            if sum(char_in_ans[start:end])>1:
                ans_token_idx.append(j)
        if len(ans_token_idx)== 0:          ## no answers found for this data
            skip=True
        else:
            start_token_idx=ans_token_idx[0]
            end_token_idx=ans_token_idx[-1]
        ##tokenize to get inputs 
        tokenized_question_context=slow_tokenizer(con,ques,padding=True,truncation=True)
        input_ids=tokenized_question_context['input_ids']
        attention_mask=tokenized_question_context['attention_mask']
        token_type_ids=tokenized_question_context['token_type_ids']
        final_keys=['input_ids','token_type_ids','attention_mask','start_token_idx','end_token_idx']
        final_inputs=[input_ids,token_type_ids,attention_mask,start_token_idx,end_token_idx]
        mp=input_ids
        if(skip==False):##check valid data
            for q in range(len(final_keys)):
                dataset_dict[final_keys[q]].append(final_inputs[q])
            #print(dataset_dict, "klk")
    #x = [dataset_dict["input_ids"],dataset_dict["token_type_ids"],dataset_dict["attention_mask"]]
    #y = [dataset_dict["start_token_idx"], dataset_dict["end_token_idx"]]
    return dataset_dict

# %%
train_input=get_model_inputs(train_contexts,train_answers,train_questions)
#test_x,test_y=get_model_inputs(test_contexts,test_answers,test_questions)
